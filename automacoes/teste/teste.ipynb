# %%
import pyautogui as py
import time
import openpyxl as xl

py.FAILSAFE = True
py.PAUSE = 1

# %%
df = xl.load_workbook(r"C:\Users\wallace.souza\Downloads\teste.xlsx")

ws = df['Plan1']

# %%
for x in ws.iter_rows(min_row=1):
    print(x[0].value)
# Out:
# 10
# 11
# 12
# 13
# 15
# 17
# 18
# 19
# 21
# 22
# 23
# 24
# 25

# %%
time.sleep(3)
py.position()
# Out:
# Point(x=540, y=935)
