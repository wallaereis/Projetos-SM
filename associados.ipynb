# %%
import pandas as pd
import numpy as np

df2 = pd.read_excel(r"P:\Indicadores\Diagnóstico\Venda\Venda Associados\Análise associados - setores atualizado.xlsx", sheet_name="SETEMBRO 2025")

# %%
df2 = df2.loc[126:139]

#PADRAO [1:18]
#GMAP[21:43]
#ALVORADA [46:81]
#TORRE [99:123]
#FLORESTA [126:139]

# %%
df2.loc[126:139]
# Out:
#      Unnamed: 0                               Unnamed: 1  Unnamed: 2  \
# 126         NaN  ANÁLISE FLORESTA - MÊS DE SETEMBRO 2025         NaN
# 127         NaN                                EMPRESAS   TOTAL LOJA
# 128         NaN                                      NaN       Venda
# 129         NaN                                LOJA 01 :   216677.31
# 130         NaN                                LOJA 02 :  1915372.85
# 131         NaN                                LOJA 03 :   867515.75
# 132         NaN                                LOJA 04 :  2304887.95
# 133         NaN                                LOJA 05 :  4195812.28
# 134         NaN                                LOJA 07 :  2097513.11
# 135         NaN                                LOJA 10 :   2317891.4
# 136         NaN                                LOJA 12 :  3020968.26
# 137         NaN                                LOJA 24 :   2175479.9
# 138         NaN                                LOJA 31 :  4595383.22
# ...

# %%
df2 = df2.dropna(axis=1, how="all")

# %%
df2["LOJA"] ="FLORESTA"
df2["DATA"] =202509

# %%
a = df2[['DATA', "LOJA",'Unnamed: 1', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8']]
b = df2[['DATA', "LOJA",'Unnamed: 1', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12']]
c = df2[['DATA', "LOJA",'Unnamed: 1', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16']]
d = df2[['DATA', "LOJA",'Unnamed: 1', 'Unnamed: 18','Unnamed: 19', 'Unnamed: 20']]
e = df2[['DATA', "LOJA",'Unnamed: 1', 'Unnamed: 22', 'Unnamed: 23','Unnamed: 24']]
f = df2[['DATA', "LOJA",'Unnamed: 1', 'Unnamed: 26', 'Unnamed: 27','Unnamed: 28']]
g = df2[['DATA', "LOJA",'Unnamed: 1', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32']]
h = df2[['DATA', "LOJA",'Unnamed: 1', 'Unnamed: 34','Unnamed: 35', 'Unnamed: 36']]
i = df2[['DATA', "LOJA",'Unnamed: 1', 'Unnamed: 38', 'Unnamed: 39','Unnamed: 40']]

# %%
a.columns = [[1,2,3,4,5,6]]
b.columns = [[1,2,3,4,5,6]]
c.columns = [[1,2,3,4,5,6]]
d.columns = [[1,2,3,4,5,6]]
e.columns = [[1,2,3,4,5,6]]
f.columns = [[1,2,3,4,5,6]]
g.columns = [[1,2,3,4,5,6]]
h.columns = [[1,2,3,4,5,6]]
i.columns = [[1,2,3,4,5,6]]

# %%
c = pd.concat([a,b,c,d,e,f,g,h,i], ignore_index=True)

# %%
c.columns = ["_".join([str(c) for c in col]).strip() for col in c.columns.values]

# %%
condicoes = [
    c["4"] == "AÇOUGUE",
    c["4"] == "CONGELADO",
    c["4"] == "FLV",
    c["4"] == "LATICINIOS",
    c["4"] == "LEITES",
    c["4"] == "PADARIA",
    c["4"] == "PEIXARIA",
    c["4"] == "SALGADOS",
    c["4"] == "MERCEARIA"
]

valores = [
    "AÇOUGUE",
    "CONGELADO",
    "FLV",
    "LATICINIOS",
    "LEITES",
    "PADARIA",
    "PEIXARIA",
    "SALGADOS",
    "MERCEARIA"
]

c["NOVO_SETOR"] = np.select(condicoes, valores, default="")

# %%
c.loc[c["NOVO_SETOR"] == '',"NOVO_SETOR" ] = np.nan

# %%
c["NOVO_SETOR"] = c["NOVO_SETOR"].ffill()

# %%
c = c[~c["3"].isin([np.nan,"EMPRESAS "])]
c = c[~c["4"].isin([np.nan])]

# %%
c = c[['1', '2', '3', 'NOVO_SETOR','4', '5', '6']]

# %%
c
# Out:
#           1         2          3 NOVO_SETOR           4         5         6
# 3    202509  FLORESTA  LOJA 01 :    AÇOUGUE           0         0         0
# 4    202509  FLORESTA  LOJA 02 :    AÇOUGUE   336571.64    0.2013  0.175721
# 5    202509  FLORESTA  LOJA 03 :    AÇOUGUE   138460.86    0.1741  0.159606
# 6    202509  FLORESTA  LOJA 04 :    AÇOUGUE   400295.65    0.2008  0.173672
# 7    202509  FLORESTA  LOJA 05 :    AÇOUGUE   743656.01    0.1919  0.177238
# ..      ...       ...        ...        ...         ...       ...       ...
# 121  202509  FLORESTA  LOJA 10 :  MERCEARIA  1141588.87  0.233614  0.492512
# 122  202509  FLORESTA  LOJA 12 :  MERCEARIA  1580411.03  0.222598  0.523147
# 123  202509  FLORESTA  LOJA 24 :  MERCEARIA   974658.09  0.262385   0.44802
# 124  202509  FLORESTA  LOJA 31 :  MERCEARIA  2158362.56  0.249263  0.469681
# 125  202509  FLORESTA  LOJA 36 :  MERCEARIA   702374.96  0.233064   0.45007
#
# [99 rows x 7 columns]

# %%
c.to_excel(r"C:\Users\wallace.souza\Downloads\FLORESTA-9.xlsx", index=False)
