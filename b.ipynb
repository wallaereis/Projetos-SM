# %%
import pandas as pd 

df = pd.read_excel(r"C:\Users\wallace.souza\Desktop\Recibo rascunho - Setembro - 2025.xlsx")

# %%
lat =df[[ 'SETOR',
       'NOME DO RECEBEDOR',
       'LOJA', 'VALOR CASH', 'VALOR $ RECEBIDO  WIIPO', 'CPF', 'SETOR.1',           
       'VENDA', 'LUCRO','TROCA',
       'QUEBRA', 'QUEBRA REGISTRADA']]

# %%
lat = lat[lat['SETOR'] == 'LATICÍNIOS']

# %%
lat.loc[lat['LOJA'].isin(['Fonseca','Piratininga',"Itaipú","Lote XV","Porto Novo","Porto Velho", "Engenho",'Valverde',
       'Barreto', 'Nova América', 'Inhaúma', 'Curtume']),'VENDA' ] = 'V'

lat.loc[lat['LOJA'].isin(['Fonseca','Piratininga',"Porto Velho",'Barreto', 'Nova América', 'Inhaúma', 'Curtume' ]),'LUCRO' ] = 'V'


lat.loc[lat['LOJA'].isin(['Fonseca','Piratininga',"Lote XV", "Batalha",'Engenho', 'Mesquita', 'Valverde',
       'Barreto','Inhaúma', 'Curtume']),'TROCA' ] = 'V'

lat.loc[lat['LOJA'].isin(['Itaipú',"Lote XV","Porto Velho", ]),'QUEBRA' ] = 'V'

lat.loc[lat['LOJA'].isin(['Lote XV']),"QUEBRA REGISTRADA"] = 'V'
# Out:
# C:\Users\wallace.souza\AppData\Local\Temp\ipykernel_22508\1709013025.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'V' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   lat.loc[lat['LOJA'].isin(['Fonseca','Piratininga',"Itaipú","Lote XV","Porto Novo","Porto Velho", "Engenho",'Valverde',
# C:\Users\wallace.souza\AppData\Local\Temp\ipykernel_22508\1709013025.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'V' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   lat.loc[lat['LOJA'].isin(['Fonseca','Piratininga',"Porto Velho",'Barreto', 'Nova América', 'Inhaúma', 'Curtume' ]),'LUCRO' ] = 'V'
# ...

# %%
lat = lat.fillna("X")
# Out:
# C:\Users\wallace.souza\AppData\Local\Temp\ipykernel_22508\3822784623.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   lat = lat.fillna("X")

# %%
flv =df[[ 'SETOR',"REFERÊNCIA QUE GEROU O PAGAMENTO",
       'NOME DO RECEBEDOR','SEQLOJA',
       'LOJA', 'VALOR CASH', 'VALOR $ RECEBIDO  WIIPO', 'CPF', 'SETOR.1',           
       'VENDA', 'LUCRO',
       'QUEBRA', 'QUEBRA REGISTRADA']]

# %%
flv = flv[(flv['SETOR'] == "FLV") & (flv['REFERÊNCIA QUE GEROU O PAGAMENTO'] == "Premiação Flv, ref.: SET de 2025") ]

# %%
flv['LOJA'].unique()
# Out:
# array(['Fonseca', 'Piratininga', 'Itaipú', 'Nova Iguaçú', 'Porto Velho',
#        'Porto Novo', 'Engenho', 'Mesquita', 'Valverde', 'Barreto',
#        'Nova América', 'Inhaúma', 'Curtume'], dtype=object)

# %%
flv.loc[flv['LOJA'].isin(['Fonseca', 'Itaipú', 'Porto Novo','Nova Iguaçú','Porto Velho',
      'Engenho', 'Valverde', 'Barreto',
       'Nova América', 'Inhaúma', 'Curtume']),'VENDA' ] = 'V'

flv.loc[flv['LOJA'].isin(['Fonseca','Nova Iguaçú','Engenho',"Valverde", 'Nova América', 'Inhaúma', 'Curtume']),'LUCRO' ] = 'V'


flv.loc[flv['SEQLOJA'].isin([3,4,13,15,17,18,]),'QUEBRA' ] = 'V'
flv.loc[flv['SEQLOJA'].isin([3,4,13,15,17,18,]),'QUEBRA REGISTRADA' ] = 'V'
# Out:
# C:\Users\wallace.souza\AppData\Local\Temp\ipykernel_22508\4217193876.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'V' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   flv.loc[flv['LOJA'].isin(['Fonseca', 'Itaipú', 'Porto Novo','Nova Iguaçú','Porto Velho',
# C:\Users\wallace.souza\AppData\Local\Temp\ipykernel_22508\4217193876.py:5: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'V' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   flv.loc[flv['LOJA'].isin(['Fonseca','Nova Iguaçú','Engenho',"Valverde", 'Nova América', 'Inhaúma', 'Curtume']),'LUCRO' ] = 'V'
# ...

# %%
ac = df[[ 'SETOR',"REFERÊNCIA QUE GEROU O PAGAMENTO",
       'NOME DO RECEBEDOR','SEQLOJA',
       'LOJA', 'VALOR CASH', 'VALOR $ RECEBIDO  WIIPO', 'CPF', 'SETOR.1',           
       'VENDA', 'LUCRO',
       'QUEBRA', 'QUEBRA REGISTRADA']]

# %%
ac = ac[(ac['SETOR']==  'AÇOUGUE') & (ac['REFERÊNCIA QUE GEROU O PAGAMENTO']==  'Premiação Açougue, ref.: SET de 2025')  ]

# %%
ac.loc[ac['SEQLOJA'].isin([1,  3,  4, 10, 11, 12, 15, 13, 18, 19, 21, 24]),'VENDA' ] = 'V'

ac.loc[ac['SEQLOJA'].isin([1,  3,  4, 10, 11, 12, 15, 21, 24]),'LUCRO' ] = 'V'

ac.loc[ac['SEQLOJA'].isin([1,  3, 12,18,19,21]),'QUEBRA' ] = 'V'

ac.loc[ac['SEQLOJA'].isin([3,12,19,21]),'QUEBRA REGISTRADA' ] = 'V'
# Out:
# C:\Users\wallace.souza\AppData\Local\Temp\ipykernel_22508\5513791.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'V' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   ac.loc[ac['SEQLOJA'].isin([1,  3,  4, 10, 11, 12, 15, 13, 18, 19, 21, 24]),'VENDA' ] = 'V'
# C:\Users\wallace.souza\AppData\Local\Temp\ipykernel_22508\5513791.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'V' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   ac.loc[ac['SEQLOJA'].isin([1,  3,  4, 10, 11, 12, 15, 21, 24]),'LUCRO' ] = 'V'
# ...

# %%
ac2 = df[[ 'SETOR',"REFERÊNCIA QUE GEROU O PAGAMENTO",
       'NOME DO RECEBEDOR','SEQLOJA',
       'LOJA', 'VALOR CASH', 'VALOR $ RECEBIDO  WIIPO', 'CPF', 'SETOR.1',           
       'VENDA', 'LUCRO',
       'QUEBRA', 'QUEBRA REGISTRADA']]

# %%
ac2 = ac2[(ac2["SETOR"] == "AÇOUGUE") & (ac2["REFERÊNCIA QUE GEROU O PAGAMENTO"] == "Premiação Açougue/Salgados, ref.: SET de 2025")]

# %%
ac2.loc[ac2['SEQLOJA'].isin([23,17,22]),'VENDA' ] = 'V'
ac2.loc[ac2['SEQLOJA'].isin([23,17,22]),'LUCRO' ] = 'V'
ac2.loc[ac2['SEQLOJA'].isin([17]),'QUEBRA' ] = 'V'
# Out:
# C:\Users\wallace.souza\AppData\Local\Temp\ipykernel_22508\3235996308.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'V' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   ac2.loc[ac2['SEQLOJA'].isin([23,17,22]),'VENDA' ] = 'V'
# C:\Users\wallace.souza\AppData\Local\Temp\ipykernel_22508\3235996308.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'V' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   ac2.loc[ac2['SEQLOJA'].isin([23,17,22]),'LUCRO' ] = 'V'
# ...

# %%
pad =  df[[ 'SETOR',"REFERÊNCIA QUE GEROU O PAGAMENTO",
       'NOME DO RECEBEDOR','SEQLOJA',
       'LOJA', 'VALOR CASH', 'VALOR $ RECEBIDO  WIIPO', 'CPF', 'SETOR.1',           
       'VENDA', 'LUCRO',
       'QUEBRA', 'QUEBRA REGISTRADA']]

# %%
pad = pad[pad['SETOR'] == "PADARIA"]

# %%
pad.loc[pad['SEQLOJA'].isin([1,  3,  4,  8, 10, 11, 12, 13, 15, 17, 18, 19, 21, 22, 23]),'VENDA' ] = 'V'


pad.loc[pad['SEQLOJA'].isin([1, 4, 10, 11, 12, 13, 17, 19, 21, 22, 23]),'LUCRO' ] = 'V'


pad.loc[pad['SEQLOJA'].isin([4,10,13,15,17,18,21]),'QUEBRA' ] = 'V'

pad.loc[pad['SEQLOJA'].isin([4,10,13,15,17,21]),'QUEBRA REGISTRADA' ] = 'V'
# Out:
# C:\Users\wallace.souza\AppData\Local\Temp\ipykernel_22508\3734214452.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'V' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   pad.loc[pad['SEQLOJA'].isin([1,  3,  4,  8, 10, 11, 12, 13, 15, 17, 18, 19, 21, 22, 23]),'VENDA' ] = 'V'
# C:\Users\wallace.souza\AppData\Local\Temp\ipykernel_22508\3734214452.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'V' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   pad.loc[pad['SEQLOJA'].isin([1, 4, 10, 11, 12, 13, 17, 19, 21, 22, 23]),'LUCRO' ] = 'V'
# ...

# %%
sg =  df[[ 'SETOR',"REFERÊNCIA QUE GEROU O PAGAMENTO",
       'NOME DO RECEBEDOR','SEQLOJA',
       'LOJA', 'VALOR CASH', 'VALOR $ RECEBIDO  WIIPO', 'CPF', 'SETOR.1',           
       'VENDA', 'LUCRO',
       'QUEBRA', 'QUEBRA REGISTRADA']]

# %%
sg = sg[(sg["SETOR"] == "SALGADOS") & (sg["REFERÊNCIA QUE GEROU O PAGAMENTO"] == "Premiação Salgados, ref.: SET de 2025")]

# %%
sg.loc[sg['SEQLOJA'].isin([ 1,  3, 10, 11, 12, 13, 18, 19, 21]),'VENDA' ] = 'V'

sg.loc[sg['SEQLOJA'].isin([ 1,  3, 4,10,11,12,13,18,19,21]),'LUCRO' ] = 'V'

sg.loc[sg['SEQLOJA'].isin([1,  3,  4, 10, 11, 12, 13, 15, 18, 19, 21]),'QUEBRA' ] = 'V'

sg.loc[sg['SEQLOJA'].isin([1,  3,  4, 10, 11, 12, 13, 15, 18]),'QUEBRA REGISTRADA' ] = 'V'
# Out:
# C:\Users\wallace.souza\AppData\Local\Temp\ipykernel_22508\3637088596.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'V' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   sg.loc[sg['SEQLOJA'].isin([ 1,  3, 10, 11, 12, 13, 18, 19, 21]),'VENDA' ] = 'V'
# C:\Users\wallace.souza\AppData\Local\Temp\ipykernel_22508\3637088596.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'V' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   sg.loc[sg['SEQLOJA'].isin([ 1,  3, 4,10,11,12,13,18,19,21]),'LUCRO' ] = 'V'
# ...

# %%
mc = df[[ 'SETOR',"REFERÊNCIA QUE GEROU O PAGAMENTO",
       'NOME DO RECEBEDOR','SEQLOJA',
       'LOJA', 'VALOR CASH', 'VALOR $ RECEBIDO  WIIPO', 'CPF', 'SETOR.1',           
       'VENDA', 'LUCRO', "TROCA",
       'QUEBRA', 'QUEBRA REGISTRADA']]

# %%
mc = mc[mc["SETOR"] == "MERCEARIA"]

# %%
mc.loc[mc['SEQLOJA'].isin([21,23]),'VENDA' ] = 'V'

mc.loc[mc['SEQLOJA'].isin([21,23]),'LUCRO' ] = 'V'

mc.loc[mc['SEQLOJA'].isin([1]),'TROCA' ] = 'V'

mc.loc[mc['SEQLOJA'].isin([4,17,24]),'QUEBRA' ] = 'V'

mc.loc[mc['SEQLOJA'].isin([17,24]),'QUEBRA REGISTRADA' ] = 'V'
# Out:
# C:\Users\wallace.souza\AppData\Local\Temp\ipykernel_22508\3310381487.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'V' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   mc.loc[mc['SEQLOJA'].isin([21,23]),'VENDA' ] = 'V'
# C:\Users\wallace.souza\AppData\Local\Temp\ipykernel_22508\3310381487.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'V' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   mc.loc[mc['SEQLOJA'].isin([21,23]),'LUCRO' ] = 'V'
# ...

# %%
df.loc[df["SETOR"] == "AÇOUGUE - CORTES","CORTES"] = "V"
df.loc[df["SETOR"] == "CPD","CPD"] = "V"
df.loc[df["SETOR"] == "PRICE","PRICE"] = "V"
df.loc[df["SETOR"] == "COZINHA","CONSUMO"] = "V"
df.loc[df["SETOR"] == "GELADOS","VENDA GELADOS"] = "V"
df.loc[df["REFERÊNCIA QUE GEROU O PAGAMENTO"] =="Premiação Flv - Especiarias, ref.: SET de 2025", "VENDA"] = "V"	
df.loc[df["REFERÊNCIA QUE GEROU O PAGAMENTO"] =="Premiação Salgados - Bacon, ref.: SET de 2025", "VENDA"] = "V"	
df.loc[df['REFERÊNCIA QUE GEROU O PAGAMENTO'] == "Premiação Analista Comercial, ref.: SET de 2025", "VENDA"] = "V"	
df.loc[df["REFERÊNCIA QUE GEROU O PAGAMENTO"].isin(['Premiação Logistica-Separadores, ref.: SET de 2025','Premiação Logistica-Separadores-Cross, ref.: SET de 2025']), "SEPARADORES"] = "V"
df.loc[df["REFERÊNCIA QUE GEROU O PAGAMENTO"] ==  'Premiação Logistica-Empilhadores, ref.: SET de 2025',"EMPILHADORES"] = "V"
df.loc[df["REFERÊNCIA QUE GEROU O PAGAMENTO"] == 'Premiação Logistica-Arrumadores, ref.: SET de 2025',"ARRUMADORES"] = "V"
# Out:
# C:\Users\wallace.souza\AppData\Local\Temp\ipykernel_22508\2866428224.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'V' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df["SETOR"] == "AÇOUGUE - CORTES","CORTES"] = "V"
# C:\Users\wallace.souza\AppData\Local\Temp\ipykernel_22508\2866428224.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'V' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df["SETOR"] == "CPD","CPD"] = "V"
# C:\Users\wallace.souza\AppData\Local\Temp\ipykernel_22508\2866428224.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'V' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
# ...

# %%
reg  = df[df["SETOR"].isin(['REGIONAL - LOJAS RJ', 'REGIONAL - LOJAS SG/NIT'])]

# %%
reg = reg[['SETOR',"REFERÊNCIA QUE GEROU O PAGAMENTO",
       'NOME DO RECEBEDOR','SEQLOJA',
       'LOJA', 'VALOR CASH', 'VALOR $ RECEBIDO  WIIPO', 'CPF', 'SETOR.1',           
       'VENDA', 'LUCRO', 'RUPTURA GERAL',"TROCA",
       'QUEBRA', 'QUEBRA REGISTRADA']]

# %%
reg.loc[reg['SEQLOJA'].isin([10,1]),'VENDA'] = "V"
reg.loc[reg['SEQLOJA'].isin([10,1]),'LUCRO'] = "V"
reg.loc[reg['SEQLOJA'].isin([10,1]),'RUPTURA GERAL'] = "V"
reg.loc[reg['SEQLOJA'].isin([10,1]),'TROCA'] = "V"
reg.loc[reg['SEQLOJA'].isin([10,1]),'QUEBRA'] = "V"
reg.loc[reg['SEQLOJA'].isin([10,1]),'QUEBRA REGISTRADA'] = "V"
# Out:
# C:\Users\wallace.souza\AppData\Local\Temp\ipykernel_22508\3282518244.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'V' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   reg.loc[reg['SEQLOJA'].isin([10,1]),'LUCRO'] = "V"
# C:\Users\wallace.souza\AppData\Local\Temp\ipykernel_22508\3282518244.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'V' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   reg.loc[reg['SEQLOJA'].isin([10,1]),'RUPTURA GERAL'] = "V"
# ...

# %%
ifood = df[df["REFERÊNCIA QUE GEROU O PAGAMENTO"] == "Premiação Ifood - Loja, ref.: SET de 2025"]

# %%
ifood =ifood[['SETOR',"REFERÊNCIA QUE GEROU O PAGAMENTO",
       'NOME DO RECEBEDOR','SEQLOJA',
       'LOJA', 'VALOR CASH', 'VALOR $ RECEBIDO  WIIPO', 'CPF', 'SETOR.1',           
       'VENDA IFOOD', "CANCELAMENTO", "SLA", "RUPTURA IFOOD", "CONECT RATE"]]

# %%
ifood.loc[ifood['SEQLOJA'].isin([1,  3,  8, 10, 12, 13, 15, 17, 18, 19, 21, 22, 23, 24]),"VENDA IFOOD"] = "V"

ifood.loc[ifood['SEQLOJA'].isin([1,  3,  8, 10, 12, 13, 15, 17, 18, 19, 21, 22, 23, 24]),"CANCELAMENTO"] = "V"

ifood.loc[ifood['SEQLOJA'].isin([12,17,19,22]),"SLA"] = "V"

ifood.loc[ifood['SEQLOJA'].isin([1, 8, 10, 12, 13, 15, 17, 18, 19, 21,23, 24]),"RUPTURA IFOOD"] = "V"

ifood.loc[ifood['SEQLOJA'].isin([1,3,8,12,15,17,22,23,24]),"CONECT RATE"] = "V"
# Out:
# C:\Users\wallace.souza\AppData\Local\Temp\ipykernel_22508\2548571411.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'V' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   ifood.loc[ifood['SEQLOJA'].isin([1,  3,  8, 10, 12, 13, 15, 17, 18, 19, 21, 22, 23, 24]),"VENDA IFOOD"] = "V"
# C:\Users\wallace.souza\AppData\Local\Temp\ipykernel_22508\2548571411.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'V' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   ifood.loc[ifood['SEQLOJA'].isin([1,  3,  8, 10, 12, 13, 15, 17, 18, 19, 21, 22, 23, 24]),"CANCELAMENTO"] = "V"
# ...

# %%
dp = df[['SETOR',"REFERÊNCIA QUE GEROU O PAGAMENTO",
       'NOME DO RECEBEDOR','SEQLOJA',
       'LOJA', 'VALOR CASH', 'VALOR $ RECEBIDO  WIIPO', 'CPF', 'SETOR.1',           
       "TROCA", "RUPTURA GERAL", "LITIGIO ", "TEMPO DE DESCARGA",'QUEBRA', 'QUEBRA REGISTRADA',]]

# %%
dp =dp[dp['SETOR'] == "DEPOSISTA"]

# %%
dp.loc[dp['SEQLOJA'].isin([1]),"TROCA"] = "V"
dp.loc[dp['SEQLOJA'].isin([23]),"TEMPO DE DESCARGA"] = "V"
dp.loc[dp['SEQLOJA'].isin([4,17,24]),"QUEBRA"] = "V"
dp.loc[dp['SEQLOJA'].isin([17,19,24]),"QUEBRA REGISTRADA"] = "V"

dp = dp.fillna("X")
# Out:
# C:\Users\wallace.souza\AppData\Local\Temp\ipykernel_22508\3473654240.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'V' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   dp.loc[dp['SEQLOJA'].isin([1]),"TROCA"] = "V"
# C:\Users\wallace.souza\AppData\Local\Temp\ipykernel_22508\3473654240.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'V' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   dp.loc[dp['SEQLOJA'].isin([23]),"TEMPO DE DESCARGA"] = "V"
# ...

# %%
comercial = df[df["REFERÊNCIA QUE GEROU O PAGAMENTO"] == "Premiação Comercial, ref.: SET de 2025"]

# %%
comercial= comercial[['SETOR',"REFERÊNCIA QUE GEROU O PAGAMENTO",
                        'NOME DO RECEBEDOR','SEQLOJA',
                        'LOJA', 'VALOR CASH', 'VALOR $ RECEBIDO  WIIPO', 'CPF', 'SETOR.1',           
                        'VENDA', "LUCRO", 'MARGEM', "RUPTURA GERAL","RUPTURA OFERTA", 'TROCA']]

# %%
comercial.loc[comercial["NOME DO RECEBEDOR"].isin(["ALEXANDRE DUTRA CLEMENTE","CAIO PORTO RAPOZO SILVA","MATHEUS DE FARIAS SILVEIRA","VENANCIO MOTA MITIDIERI"]),"VENDA"] = "V"

comercial.loc[comercial["NOME DO RECEBEDOR"].isin(["VENANCIO MOTA MITIDIERI","RAIANA COUTINHO DA SILVA","MATHEUS DE FARIAS SILVEIRA","CARLOS ANDRE ARAUJO DA SILVA","CAIO PORTO RAPOZO SILVA",
                                                   "ALEXANDRE DUTRA CLEMENTE"]),"LUCRO"] = "V"

comercial.loc[comercial["NOME DO RECEBEDOR"].isin(["CARLOS ANDRE ARAUJO DA SILVA","MATHEUS DE FARIAS SILVEIRA","RAIANA COUTINHO DA SILVA","VENANCIO MOTA MITIDIERI"]),"MARGEM"] = "V"

comercial.loc[comercial["NOME DO RECEBEDOR"].isin(['JULIANA LIMA RAMOS', 'CARLOS ANDRE ARAUJO DA SILVA',
       'CAIO PORTO RAPOZO SILVA', 'MATHEUS DE FARIAS SILVEIRA',
       'MARCOS A BACELAR', 'VENANCIO MOTA MITIDIERI',
       'ALEXANDRE DUTRA CLEMENTE', 'WANDERLEY PEREIRA',
       'RAIANA COUTINHO DA SILVA']),"RUPTURA GERAL"] = "V"


comercial.loc[comercial["NOME DO RECEBEDOR"].isin(["CARLOS ANDRE ARAUJO DA SILVA", "MATHEUS DE FARIAS SILVEIRA","WANDERLEY PEREIRA", "RAIANA COUTINHO DA SILVA"]),"RUPTURA OFERTA"] = "V"

comercial.loc[comercial["NOME DO RECEBEDOR"].isin(["ALEXANDRE DUTRA CLEMENTE"]),"TROCA"] = "V"
# Out:
# C:\Users\wallace.souza\AppData\Local\Temp\ipykernel_22508\1760209661.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'V' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   comercial.loc[comercial["NOME DO RECEBEDOR"].isin(["VENANCIO MOTA MITIDIERI","RAIANA COUTINHO DA SILVA","MATHEUS DE FARIAS SILVEIRA","CARLOS ANDRE ARAUJO DA SILVA","CAIO PORTO RAPOZO SILVA",
# C:\Users\wallace.souza\AppData\Local\Temp\ipykernel_22508\1760209661.py:6: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'V' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   comercial.loc[comercial["NOME DO RECEBEDOR"].isin(["CARLOS ANDRE ARAUJO DA SILVA","MATHEUS DE FARIAS SILVEIRA","RAIANA COUTINHO DA SILVA","VENANCIO MOTA MITIDIERI"]),"MARGEM"] = "V"
# ...

# %%
prev = df[df['SETOR'] == "PREVENÇÃO"]

# %%
prev = prev[['SETOR',"REFERÊNCIA QUE GEROU O PAGAMENTO",
                        'NOME DO RECEBEDOR','SEQLOJA',
                        'LOJA', 'VALOR CASH', 'VALOR $ RECEBIDO  WIIPO', 'CPF', 'SETOR.1', 'QUEBRA', "QUEBRA REGISTRADA"          
                        ]]

# %%
prev.loc[prev['SEQLOJA'] == 4,['QUEBRA',"QUEBRA REGISTRADA"]] = "V"
# Out:
# C:\Users\wallace.souza\AppData\Local\Temp\ipykernel_22508\1796053154.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'V' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   prev.loc[prev['SEQLOJA'] == 4,['QUEBRA',"QUEBRA REGISTRADA"]] = "V"
# C:\Users\wallace.souza\AppData\Local\Temp\ipykernel_22508\1796053154.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'V' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   prev.loc[prev['SEQLOJA'] == 4,['QUEBRA',"QUEBRA REGISTRADA"]] = "V"

# %%
gr = df[df['SETOR'] == "GERENCIAL"]

# %%
gr = gr[['SETOR',"REFERÊNCIA QUE GEROU O PAGAMENTO",
                        'NOME DO RECEBEDOR','SEQLOJA',
                        'LOJA', 'VALOR CASH', 'VALOR $ RECEBIDO  WIIPO', 'CPF', 'SETOR.1', "VENDA" ,"LUCRO",'MARGEM','QUEBRA', "QUEBRA REGISTRADA", "TROCA", "VENDA IFOOD"          
                        ]]

# %%
gr.loc[gr['SEQLOJA'].isin([1,3,13,15,17,18,19,21,22,23,24]),'VENDA'] = "V"
gr.loc[gr['SEQLOJA'].isin([1,3,13,15,17,18,19,21,22,23,24]),'LUCRO'] = "V"
gr.loc[gr['SEQLOJA'].isin([1,3,13,15,17,18,19,21,22,23,24]),'MARGEM'] = "V"
gr.loc[gr['SEQLOJA'].isin([4,17]),'QUEBRA'] = "V"
gr.loc[gr['SEQLOJA'].isin([4,17]),'QUEBRA REGISTRADA'] = "V"
gr.loc[gr['SEQLOJA'].isin([1,12,17,21,24]),'TROCA'] = "V"
gr.loc[gr['SEQLOJA'].isin([1,3,8,10,12,13,15,17,18,19,21,22,23,24]),"VENDA IFOOD"] = "V"
gr.loc[gr['SEQLOJA'].isin([4]),"VENDA IFOOD"] = "N"
# Out:
# C:\Users\wallace.souza\AppData\Local\Temp\ipykernel_22508\4238661803.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'V' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   gr.loc[gr['SEQLOJA'].isin([1,3,13,15,17,18,19,21,22,23,24]),'LUCRO'] = "V"
# C:\Users\wallace.souza\AppData\Local\Temp\ipykernel_22508\4238661803.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'V' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   gr.loc[gr['SEQLOJA'].isin([1,3,13,15,17,18,19,21,22,23,24]),'MARGEM'] = "V"
# ...

# %%
df['SETOR'].sort_values().unique()
# Out:
# array(['AÇOUGUE', 'AÇOUGUE - CORTES', 'CARGA SECA', 'COMERCIAL',
#        'COORDENAÇÃO AÇOUGUE', 'COORDENAÇÃO COZINHA', 'COORDENAÇÃO FLV',
#        'COORDENAÇÃO FRENTE DE LOJA', 'COORDENAÇÃO LATICÍNIOS',
#        'COORDENAÇÃO PADARIA', 'COORDENAÇÃO PREVENÇÃO', 'COZINHA', 'CPD',
#        'DEPOSISTA', 'FLV', 'FRENTE DE LOJA', 'GELADOS', 'GERENCIAL',
#        'GERENCIAL - MERCEARIA', 'IFOOD', 'LATICÍNIOS', 'LOGÍSTICA',
#        'LOGÍSTICA-SEPARADORES', 'MERCEARIA', 'PADARIA', 'PREVENÇÃO',
#        'PRICE', 'REGIONAL - LOJAS RJ', 'REGIONAL - LOJAS SG/NIT',
#        'SALGADOS'], dtype=object)

# %%
lat = lat.fillna("X")
mc = mc.fillna("X")
flv = flv.fillna("X")
ac = ac.fillna("X")
ac2 = ac2.fillna("X")
pad = pad.fillna("X")
sg = sg.fillna("X")
reg = reg.fillna("X")
ifood = ifood.fillna("X")
dp = dp.fillna("X")
comercial = comercial.fillna("X")
gr = gr.fillna("X")
# Out:
# C:\Users\wallace.souza\AppData\Local\Temp\ipykernel_22508\619524645.py:2: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   mc = mc.fillna("X")
# C:\Users\wallace.souza\AppData\Local\Temp\ipykernel_22508\619524645.py:3: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   flv = flv.fillna("X")
# ...

# %%
df.loc[df['SETOR'] == 'LATICÍNIOS',lat.columns] = lat.values 
df.loc[df['SETOR'] == 'MERCEARIA',mc.columns] = mc.values

df.loc[(df['SETOR'] == "FLV") & (df['REFERÊNCIA QUE GEROU O PAGAMENTO'] == "Premiação Flv, ref.: SET de 2025"), flv.columns] = flv.values

df.loc[(df['SETOR']==  'AÇOUGUE') & (df['REFERÊNCIA QUE GEROU O PAGAMENTO'] == 'Premiação Açougue, ref.: SET de 2025'),ac.columns] = ac.values


df.loc[(df["SETOR"] == "AÇOUGUE") & (df["REFERÊNCIA QUE GEROU O PAGAMENTO"] == "Premiação Açougue/Salgados, ref.: SET de 2025"),ac2.columns] = ac2.values

df.loc[df["SETOR"] == "PADARIA",pad.columns] = pad.values

df.loc[(df["SETOR"] == "SALGADOS") & (df["REFERÊNCIA QUE GEROU O PAGAMENTO"] == "Premiação Salgados, ref.: SET de 2025"),sg.columns] = sg.values

df.loc[df["SETOR"].isin(['REGIONAL - LOJAS RJ', 'REGIONAL - LOJAS SG/NIT']),reg.columns] = reg.values

df.loc[df["REFERÊNCIA QUE GEROU O PAGAMENTO"] == "Premiação Ifood - Loja, ref.: SET de 2025",ifood.columns] = ifood.values

df.loc[df['SETOR'] == "DEPOSISTA",dp.columns] = dp.values

df.loc[df["REFERÊNCIA QUE GEROU O PAGAMENTO"] == "Premiação Comercial, ref.: SET de 2025",comercial.columns] = comercial.values

df.loc[df['SETOR'] == "PREVENÇÃO",prev.columns] = prev.values

df.loc[df['SETOR'] == "GERENCIAL",gr.columns] = gr.values
# Out:
# C:\Users\wallace.souza\AppData\Local\Temp\ipykernel_22508\2627235322.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[168.0, 180.0, 606.0, 238.6, 'X', 0.0, 0.0, 354.0, 314.0, 0.0, 0.0, 428.0, 112.0, 300.0, 492.0, 456.0]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['SETOR'] == 'LATICÍNIOS',lat.columns] = lat.values
# C:\Users\wallace.souza\AppData\Local\Temp\ipykernel_22508\2627235322.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '['V', 'V', 'X', 'X', 'X', 'X', 'X', 'V', 'X', 'X', 'X', 'X', 'V', 'V', 'V', 'V']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['SETOR'] == 'LATICÍNIOS',lat.columns] = lat.values
# ...

# %%
df = df.fillna("N")

# %%
#df.to_excel(r"C:\Users\wallace.souza\Desktop\scorecard.xlsx")
