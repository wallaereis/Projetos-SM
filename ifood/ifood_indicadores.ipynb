# %%
import pandas as pd 
df = pd.read_excel(r"C:\Users\wallace.souza\Downloads\Padrão_do_Fonseca_KPIS_Ifood_10_Outubro_2025.xlsx", sheet_name="Fechamaneto Loja Outubro_25")

# %%
df = df[["Unnamed: 1",'Unnamed: 8','Unnamed: 5',"Unnamed: 3","Unnamed: 13"]]

# %%
df.columns = ['_'.join([str(c) for c in col]).strip() for col in df.columns.values]

# %%
df.columns = [["Loja","Cancelados", "SLA", "RupTura", "Contact rate" ]]

# %%
df.columns = ['_'.join([str(c) for c in col]).strip() for col in df.columns.values]

# %%
df.loc[df["Loja"] =="Supermarket - Região Oceânica","Loja"] = 3
df.loc[df["Loja"] =="Supermarket - Largo da Batalha","Loja"] = 12
df.loc[df["Loja"] =="Supermarket - Lote XV","Loja"] = 10
df.loc[df["Loja"] =="Supermarket - Mesquita","Loja"] = 18
df.loc[df["Loja"] =="Supermarket - Viga","Loja"] = 13
df.loc[df["Loja"] =="Supermarket - Engenho","Loja"] = 17
df.loc[df["Loja"] =="Supermarket - Curtume (penha)","Loja"] = 24
df.loc[df["Loja"] =="Supermarket - Nova América","Loja"] = 22
df.loc[df["Loja"] =="Supermarket - Porto Velho","Loja"] = 15
df.loc[df["Loja"] =="Supermarket - Fonseca","Loja"] = 1
df.loc[df["Loja"] =="Supermarket - Inhaúma","Loja"] = 23
df.loc[df["Loja"] =="Supermarket - Barreto","Loja"] = 21
df.loc[df["Loja"] =="Supermarket - Valverde","Loja"] = 19
df.loc[df["Loja"] =="Supermarket - Santa Cruz","Loja"] = 8

# %%
df = df.loc[4:]

# %%
df = df.sort_values("Loja")

# %%
df
# Out:
#    Loja Cancelados     SLA RupTura Contact rate
# 5     1     0.0606   0.687  0.0281       0.0546
# 7     3     0.0411  0.5831  0.0522       0.0649
# 11   10     0.0367  0.9435  0.0182       0.0483
# 15   12     0.0581  0.8685  0.0214       0.0449
# 16   13     0.0443  0.5892  0.0169       0.0631
# 6    15     0.0368  0.7083  0.0198       0.0634
# 9    17     0.0432  0.8931  0.0154       0.0396
# 14   18     0.0441  0.6607   0.018       0.0664
# 12   19     0.0484  0.9206  0.0153       0.0838
# 4    21     0.0521  0.7621  0.0186        0.081
# 10   22     0.0532  0.9736   0.023       0.0416
# 8    23     0.0457  0.7804   0.021       0.0616
# 13   24     0.0547  0.8521  0.0309       0.0557

# %%
df.to_excel(r"C:\Users\wallace.souza\Downloads\Ifood-Indicadores.xlsx", index=False)
