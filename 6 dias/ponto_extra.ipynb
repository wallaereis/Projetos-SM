# %%
import pandas as pd 


df = pd.read_excel(r"P:\Indicadores\Abastecimento\Ponto extra\11 - NOVEMBRO - 2025\PONTO EXTRA COMERCIAL - NOVEMBRO 2025.xlsx", sheet_name="Ponto Extra - Geral")
df3 = pd.read_excel(r"P:\Indicadores\Abastecimento\Ponto extra\11 - NOVEMBRO - 2025\ILHAS - NOVEMBRO 2025.xlsx", sheet_name="Ponto Extra - Geral")

# %%
df = df.loc[8:]

# %%
df = df[['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
       'Livre', 'Livre.1', 'Livre.2', 'Livre.3', 'Livre.4', 'Livre.5',
       'Livre.6', 'Livre.7', 'Livre.8', 'Livre.9', 'Livre.10', 'Livre.11',
       'Livre.12', 'Livre.13', 'Livre.14']]

# %%
df.columns = df.loc[8]
df = df.drop(8).reset_index(drop=True)

# %%
df = df[~df['Pontas'].str.contains('ILHA', case=False, na=False)]
df = df[~df['Código'].str.contains('xxx', case=False, na=False)]

# %%
df['Código'] = df['Código'].apply(lambda x: x.split('/') if isinstance(x, str) and '/' in x else x)

# %%
df.explode('Código', ignore_index=True)
# Out:
# 8   Pontas  Código                               Descrição do produto  \
# 0        1   50365  CR DENTAL COLGATE MPA CX 120G PRECO ESPECIAL/M...
# 1        1   17075     CR DENTAL SORRISO TRIPLA CX 120G LIMP COMPLETA
# 2        1   21936           CR DENTAL SORRISO CX 120G DENTES BRANCOS
# 3        2    3299              LIMP M USO UAU FR 500ML (FRAGRÂNCIAS)
# 4        2    3315              LIMP M USO UAU FR 500ML (FRAGRÂNCIAS)
# ..     ...     ...                                                ...
# 226     40   80626                         BEB ENERGET RED BULL 250ML
# 227     41   85076               SUCO INTEG SANTA FE GF 1,35L UVA TTO
# 228     41   85076               SUCO INTEG SANTA FE GF 1,35L UVA TTO
# 229     43   13214            TOMATE PELADO NOBREDO LT 400G IMPORTADO
# 230     43   13213                     PASSATA TOMATE NOBREDO VD 680G
#
# 8         Comprador                 Seção Contratos Fonseca Itaipu Porto Novo  \
# ...
