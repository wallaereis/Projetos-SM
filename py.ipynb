# %%
import pandas as pd
import numpy as np
import seaborn as sns
import glob


df = pd.read_excel(r"P:\Indicadores\Diagnóstico\Premiações\Recibos de Premiação\2025\Premiação - Recibos - Out25\Recibo rascunho - Outubro - 2025.xlsx")

# %%
df1 = df[['Cadastro', 'Natureza RH', 'Natureza', 'SETOR',
       'REFERÊNCIA QUE GEROU O PAGAMENTO', 'AUTORIZADOR',
       'RESPONSÁVEL EM TRAZER O RECIBO', 'NOME DO RECEBEDOR', 'LOJA',
       'VALOR CASH', 'VALOR $ RECEBIDO  WIIPO', 'CPF']]

# %%
df1['AUTORIZADOR'].sort_values().unique()
# Out:
# array(['João Paulo Bonifácio'], dtype=object)

# %%
df1
# Out:
#      Cadastro  Natureza RH  Natureza             SETOR  \
# 0      7106.0          813       546  AÇOUGUE - CORTES
# 1      8700.0          813       546  AÇOUGUE - CORTES
# 2     10798.0          813       546  AÇOUGUE - CORTES
# 3     15129.0          813       546  AÇOUGUE - CORTES
# 4      5881.0          813       546  AÇOUGUE - CORTES
# ..        ...          ...       ...               ...
# 720    7739.0          835       505          SALGADOS
# 721    7837.0          835       505          SALGADOS
# 722    9232.0          835       505          SALGADOS
# 723       0.0          850       845         LOGÍSTICA
# 724    6395.0          806       562        CARGA SECA
#
#                       REFERÊNCIA QUE GEROU O PAGAMENTO           AUTORIZADOR  \
# 0    Premiação Açougue Cortes Especiais, ref.: OUT ...  João Paulo Bonifácio
# 1    Premiação Açougue Cortes Especiais, ref.: OUT ...  João Paulo Bonifácio
# ...

# %%
# df.to_excel(r"C:\Users\wallace.souza\Downloads\Nomes - 19-11.xlsx", index=False)
