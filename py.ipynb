# %%
import polars as pl

df = pl.read_excel(r"C:\Users\wallace.souza\Desktop\Scripts\6 dias\estoque.xlsx")
cad = pl.read_excel(r"C:\Users\wallace.souza\Desktop\Scripts\6 dias\004075299_006119963_20250908_071714_cadastro_consinco.xlsx")
mix = pl.read_excel(r"C:\Users\wallace.souza\Desktop\Scripts\6 dias\004075300_006119964_20250908_071716_cadastro_consinco_price.xlsx")
# Out:
# Could not determine dtype for column 29, falling back to string
# Could not determine dtype for column 33, falling back to string
# Could not determine dtype for column 34, falling back to string
# Could not determine dtype for column 8, falling back to string

# %%
mix = mix[['IDCODBARPROD', 'IDSUBPRODUTO', 'DESCRICAO', 'DESCRSECAO',  'COMPRADORRESP', 'IDPRODUTO','FLAGCOMPRA_25']]

# %%
mix.schema
# Out:
# Schema([('IDCODBARPROD', Int64),
#         ('IDSUBPRODUTO', Int64),
#         ('DESCRICAO', String),
#         ('DESCRSECAO', String),
#         ('COMPRADORRESP', String),
#         ('IDPRODUTO', Int64),
#         ('FLAGCOMPRA_25', String)])
